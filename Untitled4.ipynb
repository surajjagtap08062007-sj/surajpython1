# %% [markdown]
# <a href="https://colab.research.google.com/github/surajjagtap08062007-sj/surajpython1/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr=np.random.randint(10,101,size=(5,6))
print("Array:\n",arr)
print("Shape of the array:",arr.shape)
print("Total number of element (size)")
print("Data type(dtype):",arr.dtype)
# Out:
# Array:
#  [[13 35 47 94 79 65]
#  [19 57 97 74 87 88]
#  [59 46 57 84 23 29]
#  [74 55 11 45 30 54]
#  [48 84 98 37 50 18]]
# Shape of the array: (5, 6)
# Total number of element (size)
# Data type(dtype): int64

# %%
arr=np.random.randint(1,51,size=20)
print("Array:",arr)
print("Minimum value:",)
